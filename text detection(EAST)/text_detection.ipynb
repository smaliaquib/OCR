# %%
# !pip install keras==2.1.6
# Out:
# ...
#      |████████████████████████████████| 348kB 4.9MB/s
# ...
#   Found existing installation: Keras 2.2.4
#     Uninstalling Keras-2.2.4:
#       Successfully uninstalled Keras-2.2.4
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My Drive/ML/EAST
# Out:
# /content/drive/My Drive/ML/EAST

# %%
# !python train.py --input_size=512 --batch_size=8 --nb_workers=6 --training_data_path=train/ --validation_data_path=test/ --checkpoint_path=ckpt/
# Out:
# Using TensorFlow backend.
# /content/drive/My Drive/ML/EAST/data_processor.py:236: RuntimeWarning: invalid value encountered in float_scalars
#   return np.linalg.norm(np.cross(p2 - p1, p1 - p3)) / np.linalg.norm(p2 - p1)
# /content/drive/My Drive/ML/EAST/data_processor.py:236: RuntimeWarning: invalid value encountered in float_scalars
#   return np.linalg.norm(np.cross(p2 - p1, p1 - p3)) / np.linalg.norm(p2 - p1)
# Number of validation images : 799
# tcmalloc: large alloc 2513436672 bytes == 0xb6d6e000 @  0x7ff7138d41e7 0x7ff710dc0ca1 0x7ff710e25778 0x7ff710e28ec0 0x7ff710e29435 0x7ff710ec275d 0x4f8925 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f4944 0x4f876d 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7ff7134d1b97 0x5bdf6a
# Training with 1 GPU
# WARNING: Logging before flag parsing goes to stderr.
# ...
